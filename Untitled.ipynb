# %% [markdown]
# Name: Sahil Manchanda
# Roll no: 102103134
# Group: 3CO5
#
# Topsis to rank text conversational models
#
# Applied topsis to rank the top 12 pre-trained conversational models on the huggingface open llm leaderboard: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard

# %%
import pandas as pd
import numpy as np

inputData = pd.read_csv("D:/doonloods/bakchodi/1706455097464=image_2024-01-28_204814371.csv")
print(inputData)
# Out:
#                                     Model   ARC   HellaSwag   MMLU   \
# 0                       Qwen /Qwen -72BB   65.19       85.94  77.37
# 1           chargoddard /Y1-34B -Llama B   64.59       85.63  76.31
# 2                   01-ai /Yi -34B-200KB   65.36       85.58  76.06
# 3     chargoddard /internlm2-20b -11amaD   64.59       83.12  67.27
# 4     chargoddard /intern1m2-20b -11amaB   64.68       83.16  67.17
# 5              internlm /intern1m2-20b D   62.97       83.21  67.58
# 6                         01-ai /Yi -34BB  64.59       85.69  76.35
# 7   deepseek -ai /deepseek -11m-67b-base   65.44       87.10  71.78
# 8        mistralai /Mixtral -8x7B-v0.1 B   66.04       86.49  71.82
# 9   openagi -project /OpenAGI -7B-v0.1 B   68.26       85.06  61.60
# 10                   tiiuae /falcon -180B  69.45       88.86  70.50
# 11     chargoddard /intern1m2-7b -11amaD   60.49       80.99  63.16
#
#     TruthfulQA   Winogrande   GSM8K
# 0         60.19        82.48   70.43
# 1         55.60        82.79   60.80
# 2         53.64        82.56   61.64
# 3         54.13        84.21   70.66
# 4         54.17        84.29   70.20
# 5         51.27        85.56   67.93
# 6         56.23        83.03   50.64
# 7         51.08        84.14   56.71
# 8         46.78        81.93   57.47
# 9         59.40        79.79   53.07
# 10        45.47        86.90   45.94
# 11        54.25        79.87   62.85

# %%
# !topsis D:/doonloods/bakchodi/1706455097464=image_2024-01-28_204814371.csv "1,1,1,1,1,1" "+,+,+,+,+,+" results.csv
# Out:
# Divyam Malik's Topsis Implementation
# Roll Number: 102103142
# Results saved to results.csv

# %%
results = pd.read_csv("results.csv")
print(results)
# Out:
#                                     Model   ARC   HellaSwag   MMLU   \
# 0                       Qwen /Qwen -72BB   65.19       85.94  77.37
# 1           chargoddard /Y1-34B -Llama B   64.59       85.63  76.31
# 2                   01-ai /Yi -34B-200KB   65.36       85.58  76.06
# 3     chargoddard /internlm2-20b -11amaD   64.59       83.12  67.27
# 4     chargoddard /intern1m2-20b -11amaB   64.68       83.16  67.17
# 5              internlm /intern1m2-20b D   62.97       83.21  67.58
# 6                         01-ai /Yi -34BB  64.59       85.69  76.35
# 7   deepseek -ai /deepseek -11m-67b-base   65.44       87.10  71.78
# 8        mistralai /Mixtral -8x7B-v0.1 B   66.04       86.49  71.82
# 9   openagi -project /OpenAGI -7B-v0.1 B   68.26       85.06  61.60
# 10                   tiiuae /falcon -180B  69.45       88.86  70.50
# 11     chargoddard /intern1m2-7b -11amaD   60.49       80.99  63.16
#
#     TruthfulQA   Winogrande   GSM8K   Topsis Score  Rank
# 0         60.19        82.48   70.43      0.143651  12.0
# 1         55.60        82.79   60.80      0.351606   9.0
# 2         53.64        82.56   61.64      0.361802   8.0
# 3         54.13        84.21   70.66      0.318344  11.0
# 4         54.17        84.29   70.20      0.321356  10.0
# 5         51.27        85.56   67.93      0.389995   7.0
# 6         56.23        83.03   50.64      0.527052   4.0
# 7         51.08        84.14   56.71      0.523879   5.0
# 8         46.78        81.93   57.47      0.570781   2.0
# 9         59.40        79.79   53.07      0.547080   3.0
# 10        45.47        86.90   45.94      0.688771   1.0
# 11        54.25        79.87   62.85      0.499856   6.0

# %%
import matplotlib.pyplot as plt

model_names = results['Model']
topsis_scores = results['Topsis Score']

# Plotting the bar graph
plt.figure(figsize=(5,5))
plt.bar(model_names, topsis_scores, color='blue')
plt.xlabel('Model Name')
plt.ylabel('Topsis Score')
plt.title('Topsis Score evaluation for different text conversational models (Done by Sahil)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
#plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that contrary to the leaderboard positions, the lowest 6 models score the highest according to topsis evaluation
# The best model according to topsis is falcon-180B
